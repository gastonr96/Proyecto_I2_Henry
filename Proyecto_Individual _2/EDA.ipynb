# %% [markdown]
# # ANALISIS EXPLORATORIO DE DATOS PARA MOVSTAR

# %% [markdown]
# #### Librerias

# %%
#Importacion de libreriaas 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import inspect
import numpy as np
import warnings

# %% [markdown]
# #### importacion de archivos excel con los que trabajaremos el analaisis

# %%
df_internet=pd.ExcelFile(r"Datasets\Internet.xlsx")
#df_mapa=pd.ExcelFile(r"Datasets\mapa_conectividad.xlsx")
#df_portatibil=pd.ExcelFile(r"Datasets\Portabilidad.xlsx")
#df_servicios_postales=pd.ExcelFile(r"Datasets\servicios_postales.xlsx")
#df_tel_fij=pd.ExcelFile(r"Datasets\telefonia_fija.xlsx")
#df_tel_mov=pd.ExcelFile(r"Datasets\Telefonia_movil.xlsx")
#df_television=pd.ExcelFile(r"Datasets\Television.xlsx")

# %%
print("Dimension tabla internet: " +str(df_internet.sheet_names))# Paginas del exclel  internet
# Out:
# Dimension tabla internet: ['Acc_vel_loc_sinrangos', 'Velocidad_sin_Rangos', 'Accesos_tecnologia_localidad', 'Velocidad % por prov', 'Totales VMD', 'Totales Accesos Por Tecnología', 'Accesos Por Tecnología', 'Penetración-poblacion', 'Penetracion-hogares', 'Penetracion-totales', 'Totales Accesos por rango', 'Accesos por rangos', 'Dial-BAf', 'Totales Dial-BAf', 'Ingresos ']

# %% [markdown]
# #### Parseamos los archivos a formato dataframe de pandas
# ##### por cada hoja de excel obtenemos un dataframe con sus repsectivas columnas

# %%
df_Acc_vel_loc_sinrangos = df_internet.parse("Acc_vel_loc_sinrangos")
df_Velocidad_sin_Rangos = df_internet.parse("Velocidad_sin_Rangos")
df_Accesos_tecnologia_localidad = df_internet.parse("Accesos_tecnologia_localidad")
df_Velocidad_porc_por_prov = df_internet.parse("Velocidad % por prov")
df_Totales_VMD = df_internet.parse("Totales VMD")
df_Totales_Accesos_Por_Tecnología = df_internet.parse("Totales Accesos Por Tecnología")
df_Accesos_Por_Tecnología = df_internet.parse("Accesos Por Tecnología")
df_Penetración_poblacion = df_internet.parse("Penetración-poblacion")
df_Penetracion_hogares = df_internet.parse("Penetracion-hogares")
df_Penetracion_totales = df_internet.parse("Penetracion-totales")
df_Accesos_por_rangos = df_internet.parse("Accesos por rangos")
df_Totales_Dial_BAf = df_internet.parse("Totales Dial-BAf")
df_Ingresos = df_internet.parse("Ingresos ")

# %% [markdown]
# ##### columnas de tododos los dataframe

# %%
print(df_Acc_vel_loc_sinrangos.columns)
print(df_Velocidad_sin_Rangos.columns)
print(df_Accesos_tecnologia_localidad.columns)
print(df_Velocidad_porc_por_prov.columns)
print(df_Totales_VMD.columns)
print(df_Totales_Accesos_Por_Tecnología.columns)
print(df_Accesos_Por_Tecnología.columns)
print(df_Penetración_poblacion.columns)
print(df_Penetracion_hogares.columns)
print(df_Penetracion_totales.columns)
print(df_Accesos_por_rangos.columns)
print(df_Totales_Dial_BAf.columns)
print(df_Ingresos.columns)
# Out:
# Index(['Partido', 'Localidad', 'link Indec', 'Velocidad (Mbps)', 'Provincia',
#        'Accesos'],
#       dtype='object')
# Index(['Año', 'Trimestre', 'Provincia', 'Velocidad', 'Accesos'], dtype='object')
# Index(['Provincia', 'Partido', 'Localidad', 'Tecnologia', 'Link Indec',
#        'Accesos'],
#       dtype='object')
# Index(['Año', 'Trimestre', 'Provincia', 'Mbps (Media de bajada)'], dtype='object')
# Index(['Año', 'Trimestre', 'Mbps (Media de bajada)', 'Trimestre.1'], dtype='object')
# Index(['Año', 'Trimestre', 'ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless',
#        'Otros', 'Total', 'Periodo'],
#       dtype='object')
# Index(['Año', 'Trimestre', 'Provincia', 'ADSL', 'Cablemodem', 'Fibra óptica',
#        'Wireless', 'Otros', 'Total'],
#       dtype='object')
# Index(['Año', 'Trimestre', 'Provincia', 'Accesos por cada 100 hab'], dtype='object')
# Index(['Año', 'Trimestre', 'Provincia', 'Accesos por cada 100 hogares'], dtype='object')
# ...

# %% [markdown]
# #### Tratamiento de valores nulos

# %%
#Eliminamos las columnas o filas que contengan todos sus elementos nulos  
df_Acc_vel_loc_sinrangos.dropna(axis=1, how='all',inplace=True)# axis=1 ==>columna , how=all ==> todas los elementos  nulos
df_Acc_vel_loc_sinrangos.dropna(axis=0, how='all',inplace=True)# axis=0 ==>fila , how=all ==> todas los elementos  nulos

df_Velocidad_sin_Rangos.dropna(axis=1, how='all',inplace=True)
df_Velocidad_sin_Rangos.dropna(axis=0, how='all',inplace=True)

df_Accesos_tecnologia_localidad.dropna(axis=1, how='all',inplace=True)
df_Accesos_tecnologia_localidad.dropna(axis=0, how='all',inplace=True)

df_Velocidad_porc_por_prov.dropna(axis=1, how='all',inplace=True)
df_Velocidad_porc_por_prov.dropna(axis=0, how='all',inplace=True)

df_Totales_VMD.dropna(axis=1, how='all',inplace=True)
df_Totales_VMD.dropna(axis=0, how='all',inplace=True)

df_Totales_Accesos_Por_Tecnología.dropna(axis=1, how='all',inplace=True)
df_Totales_Accesos_Por_Tecnología.dropna(axis=0, how='all',inplace=True)

df_Accesos_Por_Tecnología.dropna(axis=1, how='all',inplace=True)
df_Accesos_Por_Tecnología.dropna(axis=0, how='all',inplace=True)


df_Penetración_poblacion.dropna(axis=1, how='all',inplace=True)
df_Penetración_poblacion.dropna(axis=0, how='all',inplace=True)


df_Penetracion_hogares.dropna(axis=1, how='all',inplace=True)
df_Penetracion_hogares.dropna(axis=0, how='all',inplace=True)



df_Penetracion_totales.dropna(axis=1, how='all',inplace=True)
df_Penetracion_totales.dropna(axis=0, how='all',inplace=True)


df_Accesos_por_rangos.dropna(axis=1, how='all',inplace=True)
df_Accesos_por_rangos.dropna(axis=0, how='all',inplace=True)


df_Totales_Dial_BAf.dropna(axis=1, how='all',inplace=True)
df_Totales_Dial_BAf.dropna(axis=0, how='all',inplace=True)


df_Ingresos.dropna(axis=1, how='all',inplace=True)
df_Ingresos.dropna(axis=0, how='all',inplace=True)

# %% [markdown]
# #### Transformamos los tipos de datos para su tratamiento

# %%
df_Velocidad_sin_Rangos["Provincia"]=df_Velocidad_sin_Rangos["Provincia"].str.upper()# pasamos las provincias a mayusculas para que sea mas legible

# %%
def Pasar_Valores(df):
    
    columnas=[ "Provincia", "Tecnologia", "Localidad","Partido"]
    for col in columnas:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: str(x) if pd.notnull(x) else np.nan)
    
    columnas = ["Año", "Accesos","Trimestre"]
    for col in columnas:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: intentar_convertir_a_int(x))
    
    columnas = ["Velocidad", "Ingresos", "Mbps (Media de bajada)"]  
    for col in columnas:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: intentar_convertir_a_float(x))
    
    return df

def intentar_convertir_a_float(x):
    try:
        return float(x) if pd.notnull(x) else np.nan
    except (ValueError, TypeError):
        return np.nan


def intentar_convertir_a_int(x):
    try:
        return int(x) if pd.notnull(x) else np.nan
    except (ValueError, TypeError):
        return np.nan

# %%
df_Accesos_Por_Tecnología_original = df_Accesos_Por_Tecnología.copy()# guardo una copia ya que al aplicar la funcion quedan muchos valores nulos
df_Acc_vel_loc_sinrangos=Pasar_Valores(df_Acc_vel_loc_sinrangos)
df_Velocidad_sin_Rangos=Pasar_Valores(df_Velocidad_sin_Rangos)
df_Accesos_tecnologia_localidad=Pasar_Valores(df_Accesos_tecnologia_localidad)
df_Velocidad_porc_por_prov=Pasar_Valores(df_Velocidad_porc_por_prov)
df_Totales_VMD=Pasar_Valores(df_Totales_VMD)
df_Totales_Accesos_Por_Tecnología=Pasar_Valores(df_Totales_Accesos_Por_Tecnología)
df_Accesos_Por_Tecnología=Pasar_Valores(df_Accesos_Por_Tecnología)
df_Penetración_poblacion=Pasar_Valores(df_Penetración_poblacion)
df_Penetracion_hogares=Pasar_Valores(df_Penetracion_hogares)
df_Penetracion_totales=Pasar_Valores(df_Penetracion_totales)
df_Accesos_por_rangos=Pasar_Valores(df_Accesos_por_rangos)
df_Totales_Dial_BAf=Pasar_Valores(df_Totales_Dial_BAf)
df_Ingresos=Pasar_Valores(df_Ingresos)

# %%
#Funcion para mostrar la cantidad de valores nulos de un dataframe y su dimension
def mostrar_nulos_auto(df):
    callers_local_vars = inspect.currentframe().f_back.f_locals.items()
    nombre_df = [var_name for var_name, var_val in callers_local_vars if var_val is df]
    nombre_df = nombre_df[0] if nombre_df else "DataFrame"
    
    print(f"\n📋 Valores nulos en {nombre_df}:")
    print(df.isnull().sum())# Muestra la cantidad de valores nulos por columna
    print(np.shape(df)) # Muestra la dimension del dataframe
    print(df.head(10))  # Muestra las primeras 10 filas del DataFrame

# %%
mostrar_nulos_auto(df_Acc_vel_loc_sinrangos)
# Out:
# 📋 Valores nulos en df_Acc_vel_loc_sinrangos:
# Partido             0
# Localidad           0
# link Indec          1
# Velocidad (Mbps)    0
# Provincia           0
# Accesos             7
# dtype: int64
# (18864, 6)
#         Partido   Localidad  link Indec Velocidad (Mbps) Provincia  Accesos
# 0  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       0.0      1.0
# 1  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       0.5      2.0
# 2  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100      0.75     19.0
# 3  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       3.0     85.0
# 4  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       3.5    145.0
# 5  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       6.0     76.0
# 6  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100       8.0    299.0
# 7  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100      10.0    288.0
# 8  BUENOS AIRES  25 de Mayo  25 de Mayo          6854100      15.0    415.0
# ...

# %%
# Intercambiamos columnas para acomodar los datos
df_aux=df_Acc_vel_loc_sinrangos.copy()
df_Acc_vel_loc_sinrangos["Provincia"]=df_aux["Partido"]
df_Acc_vel_loc_sinrangos["link Indec"]=df_aux["Velocidad (Mbps)"]
df_Acc_vel_loc_sinrangos["Velocidad (Mbps)"]=df_aux["Provincia"]
df_Acc_vel_loc_sinrangos["Partido"]=df_aux["Localidad"]
df_Acc_vel_loc_sinrangos["Localidad"]=df_aux["link Indec"]
df_Acc_vel_loc_sinrangos.head(50)
# Out:
#        Partido               Localidad link Indec Velocidad (Mbps)  \
# 0   25 de Mayo              25 de Mayo    6854100              0.0
# 1   25 de Mayo              25 de Mayo    6854100              0.5
# 2   25 de Mayo              25 de Mayo    6854100             0.75
# 3   25 de Mayo              25 de Mayo    6854100              3.0
# 4   25 de Mayo              25 de Mayo    6854100              3.5
# 5   25 de Mayo              25 de Mayo    6854100              6.0
# 6   25 de Mayo              25 de Mayo    6854100              8.0
# 7   25 de Mayo              25 de Mayo    6854100             10.0
# 8   25 de Mayo              25 de Mayo    6854100             15.0
# 9   25 de Mayo              25 de Mayo    6854100             20.0
# 10  25 de Mayo              25 de Mayo    6854100             25.0
# 11  25 de Mayo              25 de Mayo    6854100             30.0
# 12  25 de Mayo              25 de Mayo    6854100             40.0
# ...

# %%
mostrar_nulos_auto(df_Velocidad_sin_Rangos)
print("\n")
df_Velocidad_sin_Rangos['Velocidad'] = df_Velocidad_sin_Rangos['Velocidad'].fillna(
    df_Velocidad_sin_Rangos.groupby(['Año', 'Trimestre', 'Provincia'])['Velocidad'].transform('mean'))
print("Cantidad de valores nulos: "+ str(df_Velocidad_sin_Rangos.isnull().sum().sum()))# Comprobamos que no queden valores nulos despues de aplicar la condicion
# Out:
# 📋 Valores nulos en df_Velocidad_sin_Rangos:
# Año           0
# Trimestre     0
# Provincia     0
# Velocidad    10
# Accesos       0
# dtype: int64
# (18884, 5)
#     Año  Trimestre     Provincia  Velocidad  Accesos
# 0  2024          2  BUENOS AIRES       75.0     1062
# 1  2024          2  BUENOS AIRES       59.0       59
# 2  2024          2  BUENOS AIRES      480.0        5
# 3  2024          2  BUENOS AIRES        3.5    41735
# 4  2024          2  BUENOS AIRES       18.0     1042
# 5  2024          2  BUENOS AIRES        9.0      750
# 6  2024          2  BUENOS AIRES       17.0        2
# 7  2024          2  BUENOS AIRES        8.0    63727
# 8  2024          2  BUENOS AIRES      105.0       14
# 9  2024          2  BUENOS AIRES      500.0   137199
#
#
# Cantidad de valores nulos: 0

# %%
mostrar_nulos_auto(df_Accesos_tecnologia_localidad)
print("\n")
df_Accesos_tecnologia_localidad['Accesos'] = df_Velocidad_sin_Rangos['Accesos'].fillna(
    df_Accesos_tecnologia_localidad.groupby(['Provincia', 'Tecnologia'])['Accesos'].transform('mean'))
print("Cantidad de valores nulos: "+ str(df_Accesos_tecnologia_localidad.isnull().sum().sum()))# Comprobamos que no queden valores nulos despues de aplicar la condicion
# Out:
# 📋 Valores nulos en df_Accesos_tecnologia_localidad:
# Provincia     0
# Partido       0
# Localidad     0
# Tecnologia    0
# Link Indec    0
# Accesos       6
# dtype: int64
# (7753, 6)
#       Provincia     Partido          Localidad    Tecnologia Link Indec  \
# 0  BUENOS AIRES  25 de Mayo         25 de Mayo          ADSL    6854100
# 1  BUENOS AIRES  25 de Mayo         25 de Mayo    CABLEMODEM    6854100
# 2  BUENOS AIRES  25 de Mayo         25 de Mayo  FIBRA OPTICA    6854100
# 3  BUENOS AIRES  25 de Mayo         25 de Mayo     SATELITAL    6854100
# 4  BUENOS AIRES  25 de Mayo         25 de Mayo      WIRELESS    6854100
# 5  BUENOS AIRES  25 de Mayo          Del Valle          ADSL    6854020
# 6  BUENOS AIRES  25 de Mayo          Del Valle         Otros    6854020
# 7  BUENOS AIRES  25 de Mayo          Del Valle     SATELITAL    6854020
# 8  BUENOS AIRES  25 de Mayo          Ernestina          ADSL    6854030
# ...

# %%
mostrar_nulos_auto(df_Velocidad_porc_por_prov)
# Out:
# 📋 Valores nulos en df_Velocidad_porc_por_prov:
# Año                       0
# Trimestre                 0
# Provincia                 0
# Mbps (Media de bajada)    0
# dtype: int64
# (1008, 4)
#     Año  Trimestre        Provincia  Mbps (Media de bajada)
# 0  2024          2     Buenos Aires                  157.41
# 1  2024          2  Capital Federal                  233.01
# 2  2024          2        Catamarca                   97.38
# 3  2024          2            Chaco                  107.76
# 4  2024          2           Chubut                   21.67
# 5  2024          2          Córdoba                  117.39
# 6  2024          2       Corrientes                  104.26
# 7  2024          2       Entre Ríos                  100.98
# 8  2024          2          Formosa                   82.66
# 9  2024          2            Jujuy                   49.87

# %%
mostrar_nulos_auto(df_Totales_VMD)
# Out:
# 📋 Valores nulos en df_Totales_VMD:
# Año                       0
# Trimestre                 0
# Mbps (Media de bajada)    0
# Trimestre.1               0
# dtype: int64
# (42, 4)
#     Año  Trimestre  Mbps (Media de bajada)    Trimestre.1
# 0  2024          2                  139.25   Abr-Jun 2024
# 1  2024          1                  139.15   Ene-Mar 2024
# 2  2023          4                  139.04   Oct-Dic 2023
# 3  2023          3                  129.67  Jul-Sept 2023
# 4  2023          2                  123.95   Abr-Jun 2023
# 5  2023          1                  110.50   Ene-Mar 2023
# 6  2022          4                  106.56   Oct-Dic 2022
# 7  2022          3                   62.46  Jul-Sept 2022
# 8  2022          2                   58.44   Abr-Jun 2022
# 9  2022          1                   55.11   Ene-Mar 2022

# %%
mostrar_nulos_auto(df_Totales_Accesos_Por_Tecnología)
# Out:
# 📋 Valores nulos en df_Totales_Accesos_Por_Tecnología:
# Año             0
# Trimestre       0
# ADSL            0
# Cablemodem      0
# Fibra óptica    0
# Wireless        0
# Otros           0
# Total           0
# Periodo         0
# dtype: int64
# (42, 9)
#     Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0  2024          2   733491     5867504       4169958    593197  191957
# 1  2024          1   774475     5986957       4015101    598682  257941
# 2  2023          4   836390     6022532       3908183    585760  194796
# 3  2023          3   897895     6018832       3708718    581436  200027
# 4  2023          2  1006509     5997149       3463988    581823  202428
# 5  2023          1  1204417     6002582       3243411    576647  214838
# 6  2022          4  1315373     6037457       3060575    572969  221740
# 7  2022          3  1395277     6031970       2871541    557110  235230
# ...

# %%
df_Totales_Accesos_Por_Tecnología.drop(columns="Periodo",inplace=True)# Eliminamos la columna periodo ya qque no la autilizaremos

# %%
mostrar_nulos_auto(df_Accesos_Por_Tecnología)
print("\n") 
# Eliminar filas con más de 2 elementos nulos, ya que contiene muchos elementos nulos
df_Accesos_Por_Tecnología = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología.isnull().sum(axis=1) <= 3]
print("Cantidad de valores nulos: "+ str(df_Accesos_Por_Tecnología.isnull().sum().sum()))# Comprobamos que no queden valores nulos despues de aplicar la condicion
# Out:
# 📋 Valores nulos en df_Accesos_Por_Tecnología:
# Año             73
# Trimestre       73
# Provincia        1
# ADSL             1
# Cablemodem       1
# Fibra óptica     1
# Wireless         1
# Otros            1
# Total            1
# dtype: int64
# (1008, 9)
#       Año  Trimestre        Provincia      ADSL  Cablemodem  Fibra óptica  \
# 0  2024.0        2.0     Buenos Aires  214055.0   2722466.0     1849476.0
# 1  2024.0        2.0  Capital Federal   54102.0   1144781.0      230402.0
# 2  2024.0        2.0        Catamarca    4951.0     10303.0       58355.0
# 3  2024.0        2.0            Chaco    9448.0     57935.0       68944.0
# 4  2024.0        2.0           Chubut   25955.0     80704.0       26516.0
# 5  2024.0        2.0          Córdoba   93483.0    443091.0      477504.0
# 6  2024.0        2.0       Corrientes   14849.0     86226.0       39792.0
# 7  2024.0        2.0       Entre Ríos   31335.0    158918.0       68540.0
# ...

# %%
#averiguamos los valores nulos del df original 
indices_nulos = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología["Año"].isna()].index
df_Accesos_Por_Tecnología_original.loc[indices_nulos]
#Vemos que las columnas  que se encuentran como nan 
# trimeste y año estan con otro caracter lo que afecta la converision y nos devuelve valores nulos
# Recortamos el primer caracter de trimestre ya que en algunas filas esta como 1* y en otras como 1
# luego lo convertimos a int
df_Accesos_Por_Tecnología["Trimestre"] = df_Accesos_Por_Tecnología_original["Trimestre"].apply(
    lambda x: int(str(x)[0]) if pd.notnull(x) and str(x)[0].isdigit() else np.nan
)
df_Accesos_Por_Tecnología["Año"] = df_Accesos_Por_Tecnología_original["Año"].apply(
    lambda x: int(str(x)[:4]) if pd.notnull(x) and str(x)[:4].isdigit() else np.nan
)

mostrar_nulos_auto(df_Accesos_Por_Tecnología)
# Out:
# 📋 Valores nulos en df_Accesos_Por_Tecnología:
# Año             0
# Trimestre       0
# Provincia       0
# ADSL            0
# Cablemodem      0
# Fibra óptica    0
# Wireless        0
# Otros           0
# Total           0
# dtype: int64
# (1007, 9)
#       Año  Trimestre        Provincia      ADSL  Cablemodem  Fibra óptica  \
# 0  2024.0        2.0     Buenos Aires  214055.0   2722466.0     1849476.0
# 1  2024.0        2.0  Capital Federal   54102.0   1144781.0      230402.0
# 2  2024.0        2.0        Catamarca    4951.0     10303.0       58355.0
# 3  2024.0        2.0            Chaco    9448.0     57935.0       68944.0
# 4  2024.0        2.0           Chubut   25955.0     80704.0       26516.0
# 5  2024.0        2.0          Córdoba   93483.0    443091.0      477504.0
# 6  2024.0        2.0       Corrientes   14849.0     86226.0       39792.0
# 7  2024.0        2.0       Entre Ríos   31335.0    158918.0       68540.0
# ...

# %%
mostrar_nulos_auto(df_Penetración_poblacion)
# Out:
# 📋 Valores nulos en df_Penetración_poblacion:
# Año                         0
# Trimestre                   0
# Provincia                   0
# Accesos por cada 100 hab    0
# dtype: int64
# (1000, 4)
#     Año  Trimestre        Provincia  Accesos por cada 100 hab
# 0  2024          2     Buenos Aires                     27.43
# 1  2024          2  Capital Federal                     47.44
# 2  2024          2        Catamarca                     17.50
# 3  2024          2            Chaco                     11.78
# 4  2024          2           Chubut                     26.46
# 5  2024          2          Córdoba                     27.79
# 6  2024          2       Corrientes                     13.53
# 7  2024          2       Entre Ríos                     20.52
# 8  2024          2          Formosa                     10.10
# 9  2024          2            Jujuy                     14.91

# %%
mostrar_nulos_auto(df_Penetracion_totales)
df_Penetracion_totales.drop(columns="Periodo",inplace=True)# Eliminamos la columna periodo ya qque no la autilizaremos
# Out:
# 📋 Valores nulos en df_Penetracion_totales:
# Año                             0
# Trimestre                       0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Periodo                         0
# dtype: int64
# (42, 5)
#     Año  Trimestre  Accesos por cada 100 hogares  Accesos por cada 100 hab  \
# 0  2024          2                     78.130000                 24.570000
# 1  2024          1                     78.890000                 24.790000
# 2  2023          4                     78.560000                 24.660000
# 3  2023          3                     77.840000                 24.410000
# 4  2023          2                     77.020000                 24.140000
# 5  2023          1                     77.200000                 24.170000
# 6  2022          4                     77.210000                 24.150000
# 7  2022          3                     76.640000                 23.950000
# ...

# %%
mostrar_nulos_auto(df_Totales_Dial_BAf)
df_Totales_Dial_BAf.drop(columns="Periodo",inplace=True)# Eliminamos la columna periodo ya qque no la autilizaremos
# Out:
# 📋 Valores nulos en df_Totales_Dial_BAf:
# Año                 0
# Trimestre           0
# Banda ancha fija    0
# Dial up             0
# Total               0
# Periodo             0
# dtype: int64
# (42, 6)
#     Año  Trimestre  Banda ancha fija  Dial up     Total        Periodo
# 0  2024          2          11544314    11793  11556107   Abr-Jun 2024
# 1  2024          1          11621363    11793  11633156   Ene-Mar 2024
# 2  2023          4          11535868    11793  11547661   Oct-Dic 2023
# 3  2023          3          11395115    11793  11406908  Jul-Sept 2023
# 4  2023          2          11239781    12116  11251897   Abr-Jun 2023
# 5  2023          1          11229459    12436  11241895   Ene-Mar 2023
# 6  2022          4          11195668    12446  11208114   Oct-Dic 2022
# 7  2022          3          11078691    12437  11091128  Jul-Sept 2022
# 8  2022          2          10946248    12436  10958684   Abr-Jun 2022
# ...

# %%
mostrar_nulos_auto(df_Penetracion_hogares)
# Out:
# 📋 Valores nulos en df_Penetracion_hogares:
# Año                             0
# Trimestre                       0
# Provincia                       0
# Accesos por cada 100 hogares    0
# dtype: int64
# (1000, 4)
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2024          2     Buenos Aires                         79.84
# 1  2024          2  Capital Federal                        116.37
# 2  2024          2        Catamarca                         68.81
# 3  2024          2            Chaco                         44.06
# 4  2024          2           Chubut                         86.33
# 5  2024          2          Córdoba                         90.79
# 6  2024          2       Corrientes                         51.38
# 7  2024          2       Entre Ríos                         68.64
# 8  2024          2          Formosa                         39.69
# 9  2024          2            Jujuy                         58.30

# %%
mostrar_nulos_auto(df_Ingresos)
# Out:
# 📋 Valores nulos en df_Ingresos:
# Año                          0
# Trimestre                    0
# Ingresos (miles de pesos)    0
# Periodo                      0
# dtype: int64
# (42, 4)
#     Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0  2024          2               4.420322e+08   Abr-Jun 2024
# 1  2024          1               3.461990e+08   Ene-Mar 2024
# 2  2023          4               1.673760e+08   Oct-Dic 2023
# 3  2023          3               1.331066e+08  Jul-Sept 2023
# 4  2023          2               1.180603e+08   Jun-Mar 2023
# 5  2033          1               1.041350e+08   Ene-Mar 2023
# 6  2022          4               7.244348e+07   Oct-Dic 2022
# 7  2022          3               6.408678e+07  Jul-Sept 2022
# 8  2022          2               6.041950e+07   Abr-Jun 2022
# 9  2022          1               5.521931e+07   Ene-Mar 2022

# %%
mostrar_nulos_auto(df_Accesos_por_rangos)
# Out:
# 📋 Valores nulos en df_Accesos_por_rangos:
# Año                    0
# Trimestre              0
# Provincia              0
# HASTA 512 kbps         0
# + 512 Kbps - 1 Mbps    0
# + 1 Mbps - 6 Mbps      0
# + 6 Mbps - 10 Mbps     0
# + 10 Mbps - 20 Mbps    0
# + 20 Mbps - 30 Mbps    0
# + 30 Mbps              0
# OTROS                  6
# Total                  0
# dtype: int64
# (1000, 12)
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2024          2     Buenos Aires         25287.0              23034.0
# 1  2024          2  Capital Federal           518.0               4122.0
# 2  2024          2        Catamarca            72.0                164.0
# 3  2024          2            Chaco           236.0                349.0
# 4  2024          2           Chubut           125.0               1139.0
# 5  2024          2          Córdoba           103.0               7771.0
# 6  2024          2       Corrientes            67.0               2514.0
# ...

# %% [markdown]
# ### Trabajamos los outliers para minimizar el error

# %%
# Funcionpara eliminar outliers
def Eliminar_outliers(df, columna):
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3 - Q1
    # Definimos los límites
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    # Filtramos el DataFrame sin outliers
    df= df[(df[columna] >= limite_inferior) &
    (df[columna] <= limite_superior)]
    return df

# %% [markdown]
# ##### Outliers de velocidad

# %%
plt.title("Valores Outliers de Velocidad")
sns.boxplot(x=df_Velocidad_sin_Rangos["Velocidad"] )  # o "velocidad"
plt.show()

# %%
# Crear los bins de 50
df_Velocidad_sin_Rangos['Velocidad_bins'] = pd.cut(df_Velocidad_sin_Rangos['Velocidad'], bins=range(int(df_Velocidad_sin_Rangos['Velocidad'].min()), int(df_Velocidad_sin_Rangos['Velocidad'].max()) + 10, 400))

# Crear el countplot con los bins creados y con una escala de colores
plt.figure(figsize=(20, 6))
ax = sns.countplot(x='Velocidad_bins', data=df_Velocidad_sin_Rangos, palette='viridis')

# Agregar las etiquetas de cantidad de conexiones sobre las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10), textcoords='offset points')

plt.title("Countplot de la Velocidad de Conexión sin Outliers en Intervalos de 50 con Escala de Colores")
plt.xlabel("Rango de Velocidad (Mbps)")
plt.ylabel("Frecuencia")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\1793649497.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Velocidad_bins', data=df_Velocidad_sin_Rangos, palette='viridis')

# %%
# Hacemos una copia del DataFrame original
df_Velocidad_sin_Rangos_filtrado = df_Velocidad_sin_Rangos.copy()

df_Velocidad_sin_Rangos_filtrado["Velocidad"] = (
    df_Velocidad_sin_Rangos_filtrado
    .groupby("Año", group_keys=False)
    .apply(lambda x: Eliminar_outliers(x, "Velocidad")["Velocidad"])
)
# Crear los bins de 50
df_Velocidad_sin_Rangos_filtrado['Velocidad_bins'] = pd.cut(df_Velocidad_sin_Rangos_filtrado['Velocidad'], bins=range(int(df_Velocidad_sin_Rangos_filtrado['Velocidad'].min()), int(df_Velocidad_sin_Rangos_filtrado['Velocidad'].max()) , 10))

# Agrupar por bin y sumar los accesos
df_agrupado = df_Velocidad_sin_Rangos_filtrado.groupby("Velocidad_bins")["Accesos"].sum().reset_index()

# Crear el gráfico
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="Velocidad_bins", y="Accesos", data=df_agrupado, palette='viridis')

# Agregar etiquetas sobre las barras
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10), textcoords='offset points')

plt.title("Cantidad de Accesos por Rango de Velocidad (sin outliers)")
plt.xlabel("Rango de Velocidad (Mbps)")
plt.ylabel("Cantidad de Accesos")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2932318101.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: Eliminar_outliers(x, "Velocidad")["Velocidad"])
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2932318101.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_agrupado = df_Velocidad_sin_Rangos_filtrado.groupby("Velocidad_bins")["Accesos"].sum().reset_index()
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2932318101.py:17: FutureWarning:
#
# ...

# %%
# Nos quedamos con los últimos 9 años
ultimos_8_anios = sorted(df_Velocidad_sin_Rangos_filtrado['Año'].unique())[-8:]

# Creamos la figura con subplots (3 filas x 3 columnas)
fig, axes = plt.subplots(3, 3, figsize=(18, 15))
axes = axes.flatten()  # Aplanamos la matriz para recorrer más fácil

for i, anio in enumerate(ultimos_8_anios):
    df_anio = df_Velocidad_sin_Rangos_filtrado[df_Velocidad_sin_Rangos_filtrado['Año'] == anio]
    
    # Crear bins específicos por año
    bins = range(int(df_anio['Velocidad'].min()), int(df_anio['Velocidad'].max()) + 10, 10)
    df_anio['Velocidad_bins'] = pd.cut(df_anio['Velocidad'], bins=bins)

    # Graficar en el subplot correspondiente
    ax = sns.countplot(x='Velocidad_bins', data=df_anio, palette='viridis', ax=axes[i])
    ax.set_title(f'Año {anio}')
    ax.set_xlabel('')
    ax.set_ylabel('Frecuencia')
    ax.tick_params(axis='x', rotation=45)
    
    # Etiquetas sobre las barras
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 8), textcoords='offset points')

# Ajustar diseño
plt.tight_layout()
plt.suptitle("Distribución de Velocidad por Año (sin outliers)", fontsize=18, y=1.02)
plt.show()
# Out:
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2257222219.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anio['Velocidad_bins'] = pd.cut(df_anio['Velocidad'], bins=bins)
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2257222219.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Velocidad_bins', data=df_anio, palette='viridis', ax=axes[i])
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2257222219.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.title("Valores Outliers de Velocidad")
sns.boxplot(x=df_Velocidad_sin_Rangos_filtrado["Velocidad"] )  # o "velocidad"
plt.show()

# %% [markdown]
# Exportamos archivos para power BI

# %%
import os

# Crear carpeta para guardar archivos exportados si no existe
output_folder = "archivos_para_powerbi"
os.makedirs(output_folder, exist_ok=True)

# Supongamos que tenés estos DataFrames limpios
dataframes = {
    "Accesos_tecnologia": df_Velocidad_sin_Rangos_filtrado,
    
    "Accesos_tecnologia_localidad":df_Accesos_tecnologia_localidad,

    "Velocidad_porc_por_prov":df_Velocidad_porc_por_prov,
    "Totales_VMD":df_Totales_VMD,
    "Totales_Accesos_Por_Tecnología":df_Totales_Accesos_Por_Tecnología,
    "Accesos_por_rangos":df_Accesos_por_rangos,
    "Ingresos":df_Ingresos,
    "Penetracion_hogares":df_Penetracion_hogares,
    "Totales_Dial_BAf":df_Totales_Dial_BAf,
    "Penetracion_totales":df_Penetracion_totales,
    "Penetración_poblacion":df_Penetración_poblacion,
    "Velocidad_sin_Rangos":df_Velocidad_sin_Rangos,
    "Acc_vel_loc_sinrangos":df_Acc_vel_loc_sinrangos
}

# Guardarlos en archivos CSV
for nombre, df in dataframes.items():
    ruta = os.path.join(output_folder, f"{nombre}.csv")
    df.to_csv(ruta, index=False)

# %% [markdown]
# ### Ahora que ya tenemos limpio el dataset extraeremos informacion relacionando los datos

# %% [markdown]
# #### Aumento de la velocidad promedio durante el paso de los años

# %%
#Agrupamos por año y trimestre, y sumamos los accesos
df_velocidad_por_periodos = df_Velocidad_sin_Rangos_filtrado.groupby(["Año", "Trimestre"])["Velocidad"].mean().reset_index()

# Creamos una columna combinada para el eje X
df_velocidad_por_periodos["Periodo"] = df_velocidad_por_periodos["Año"].astype(str) + " - T" + df_velocidad_por_periodos["Trimestre"].astype(str)

# Graficamos
plt.figure(figsize=(12, 6))
plt.plot(df_velocidad_por_periodos["Periodo"], df_velocidad_por_periodos["Velocidad"], marker='o', color='red')
plt.title("Evolución de la velocidad promerdio de Internet por Trimestre")
plt.xlabel("Periodo (Año - Trimestre)")
plt.ylabel("Cantidad de Accesos")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Aumento de la velocidad promedio durante el paso de los años

# %%
#Agrupamos por año y trimestre, y sumamos los accesos
df_Accesos_por_año = df_Velocidad_sin_Rangos_filtrado.groupby(["Año", "Trimestre"])["Accesos"].sum().reset_index()

# Creamos una columna combinada para el eje X
df_Accesos_por_año["Periodo"] = df_Accesos_por_año["Año"].astype(str) + " - T" + df_Accesos_por_año["Trimestre"].astype(str)

# Graficamos
plt.figure(figsize=(12, 6))
plt.plot(df_Accesos_por_año["Periodo"], df_Accesos_por_año["Accesos"], marker='o', color='red')
plt.title("Evolución de los Accesos a Internet por Trimestre")
plt.xlabel("Periodo (Año - Trimestre)")
plt.ylabel("Cantidad de Accesos")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Creamos una nueva columna para representar el tiempo (año y trimestre juntos)
df_Velocidad_porc_por_prov['Tiempo'] = df_Velocidad_porc_por_prov['Año'].astype(str) + " -T" + df_Velocidad_porc_por_prov['Trimestre'].astype(str)

# Graficamos en funcion del tiempo, dibujando una línea por cada provincia y despues le agregamos el titulo y las etiquetas
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

sns.lineplot(x='Tiempo', y='Mbps (Media de bajada)', hue='Provincia', data=df_Velocidad_porc_por_prov, legend= False)

# Para mostrar la leyenda se elimina 'legend=False' y se debe agregar 'plt.legend(title="Provincia")' si se quiere visualizar las provincias

plt.gca().invert_xaxis()
plt.title('Evolución del promedio de la Velocidad de Internet por Provincia', fontsize=16)
plt.xlabel('Tiempo', fontsize=12)
plt.ylabel('Promedio de Velocidad (Mbps)', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Paso 1: Promedio de velocidad por provincia
promedios = df_Velocidad_porc_por_prov.groupby("Provincia")["Mbps (Media de bajada)"].mean()

# Paso 2: Seleccionar las provincias con mayor promedio (top 5)
top_provincias = promedios.sort_values(ascending=False).head(5).index.tolist()

# Paso 3: Filtrar el DataFrame original para incluir solo esas provincias
df_top = df_Velocidad_porc_por_prov[df_Velocidad_porc_por_prov["Provincia"].isin(top_provincias)]

# Crear columna de tiempo
df_top["Tiempo"] = df_top["Año"].astype(str) + " -T" + df_top["Trimestre"].astype(str)

# Paso 4: Graficar
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

sns.lineplot(x='Tiempo', y='Mbps (Media de bajada)', hue='Provincia', data=df_top)

plt.gca().invert_xaxis()
plt.title('Evolución del Promedio de Velocidad de Internet (Top 5 Provincias)', fontsize=16)
plt.xlabel('Tiempo', fontsize=12)
plt.ylabel('Promedio de Velocidad (Mbps)', fontsize=12)
plt.xticks(rotation=90)
plt.legend(title="Provincia")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gaston\AppData\Local\Temp\ipykernel_8480\2846457192.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top["Tiempo"] = df_top["Año"].astype(str) + " -T" + df_top["Trimestre"].astype(str)

# %% [markdown]
# #### Velocidad promedio por provincia

# %%
ultimos_5 = sorted(df_Totales_Accesos_Por_Tecnología["Año"].unique())[-5:]

for anio in ultimos_5:
    df_anio = df_Totales_Accesos_Por_Tecnología[df_Totales_Accesos_Por_Tecnología["Año"] == anio]
    
    # Sumar cantidad por tecnología para ese año
    suma_tecnologias = {
        "ADSL": df_anio["ADSL"].sum(),
        "Cablemodem": df_anio["Cablemodem"].sum(),
        "Fibra óptica": df_anio["Fibra óptica"].sum(),
        "Wireless": df_anio["Wireless"].sum(),
        "Otros": df_anio["Otros"].sum()
    }

    # Crear gráfico
    plt.figure(figsize=(8, 5))
    plt.bar(suma_tecnologias.keys(), suma_tecnologias.values(), color="skyblue", edgecolor="black")
    plt.title(f"Accesos por Tecnología - Año {anio}")
    plt.xlabel("Tecnología")
    plt.ylabel("Cantidad de Accesos")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Top 5 provincias con mas accesos de acuerdo al tipo de tecnologia usada

# %%
# Agrupar por Provincia y sumar accesos totales de fibra óptica
accesos_totales_por_provincia = df_Accesos_Por_Tecnología.groupby("Provincia")["Fibra óptica"].sum()

# Ordenar y tomar las 5 provincias con más accesos
top_5_provincias = accesos_totales_por_provincia.sort_values(ascending=False).head(5).index
# Filtrar el DataFrame original para esas provincias:
# Filtrar el dataframe original a solo las 5 provincias con más accesos
df_top5_fibra = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología["Provincia"].isin(top_5_provincias)]

# Agrupar por Tiempo y Provincia (solo top 5)
df_fibra_top5 = df_top5_fibra.groupby(["Año","Trimestre", "Provincia"])["Fibra óptica"].sum().unstack()

# Plot
plt.figure(figsize=(14, 7))
ax = df_fibra_top5.plot(kind='line', marker='o', figsize=(14, 7))

# Eje X completo
ax.set_xticks(range(len(df_fibra_top5.index)))
ax.set_xticklabels(df_fibra_top5.index, rotation=90)

plt.title("Top 5 Provincias con Más Accesos de Fibra Óptica")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad de Accesos")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title="Provincia", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# La fibra optica es la tecnologia con mas accesos, siendo la tecnologia con mas creciente en los ultimos años

# %%
# Agrupar por Provincia y sumar accesos totales de fibra óptica
accesos_totales_por_provincia = df_Accesos_Por_Tecnología.groupby("Provincia")["ADSL"].sum()

# Ordenar y tomar las 5 provincias con más accesos
top_5_provincias = accesos_totales_por_provincia.sort_values(ascending=False).head(5).index
# Filtrar el DataFrame original para esas provincias:
# Filtrar el dataframe original a solo las 5 provincias con más accesos
df_top5_adsl = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología["Provincia"].isin(top_5_provincias)]

# Agrupar por Tiempo y Provincia (solo top 5)
df_adsl_top5 = df_top5_adsl.groupby(["Año","Trimestre", "Provincia"])["ADSL"].sum().unstack()

# Plot
plt.figure(figsize=(14, 7))
ax = df_adsl_top5.plot(kind='line', marker='o', figsize=(14, 7))

# Eje X completo
ax.set_xticks(range(len(df_adsl_top5.index)))
ax.set_xticklabels(df_adsl_top5.index, rotation=90)

plt.title("Top 5 Provincias con Más Accesos de ADSL")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad de Accesos")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title="Provincia", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Este grafico indica el decaimento a traves de los años del uso de la tecnologia ADSL

# %%
# Agrupar por Provincia y sumar accesos totales de fibra óptica
accesos_totales_por_provincia = df_Accesos_Por_Tecnología.groupby("Provincia")["Cablemodem"].sum()

# Ordenar y tomar las 5 provincias con más accesos
top_5_provincias = accesos_totales_por_provincia.sort_values(ascending=False).head(5).index
# Filtrar el DataFrame original para esas provincias:
# Filtrar el dataframe original a solo las 5 provincias con más accesos
df_top5_cm = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología["Provincia"].isin(top_5_provincias)]

# Agrupar por Tiempo y Provincia (solo top 5)
df_cm_top5 = df_top5_cm.groupby(["Año","Trimestre", "Provincia"])["Cablemodem"].sum().unstack()

# Plot
plt.figure(figsize=(14, 7))
ax = df_cm_top5.plot(kind='line', marker='o', figsize=(14, 7))

# Eje X completo
ax.set_xticks(range(len(df_cm_top5.index)))
ax.set_xticklabels(df_cm_top5.index, rotation=90)

plt.title("Top 5 Provincias con Más Accesos de Cable modem")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad de Accesos")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title="Provincia", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Agrupar por Provincia y sumar accesos totales de fibra óptica
accesos_totales_por_provincia = df_Accesos_Por_Tecnología.groupby("Provincia")["Wireless"].sum()

# Ordenar y tomar las 5 provincias con más accesos
top_5_provincias = accesos_totales_por_provincia.sort_values(ascending=False).head(5).index
# Filtrar el DataFrame original para esas provincias:
# Filtrar el dataframe original a solo las 5 provincias con más accesos
df_top5_ws = df_Accesos_Por_Tecnología[df_Accesos_Por_Tecnología["Provincia"].isin(top_5_provincias)]

# Agrupar por Tiempo y Provincia (solo top 5)
df_ws_top5 = df_top5_ws.groupby(["Año","Trimestre", "Provincia"])["Wireless"].sum().unstack()

# Plot
plt.figure(figsize=(14, 7))
ax = df_ws_top5.plot(kind='line', marker='o', figsize=(14, 7))

# Eje X completo
ax.set_xticks(range(len(df_ws_top5.index)))
ax.set_xticklabels(df_ws_top5.index, rotation=90)

plt.title("Top 5 Provincias con Más Accesos de Wireless")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad de Accesos")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title="Provincia", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Grafico de comparacion de tecnologias a traves del tiempo

# %%
df_Totales_Accesos_Por_Tecnología.set_index(['Año', 'Trimestre'])[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros']].plot(kind='bar', stacked=True, figsize=(12, 6), cmap='tab10')
plt.title('Distribución de Conexiones por Tecnología')
plt.ylabel('Número de Conexiones')
plt.xlabel('Año-Trimestre')
plt.xticks(rotation=90)
plt.legend(title='Tecnologías')
plt.tight_layout()
plt.show()

# %% [markdown]
# El grafico mostrado se puede ver mejor las proporciones entre las distintas tecnologias, dando lugar a la evidencia que con el tiempo ciertas tecnologias (ADSL) desaparecen dejando lugar a otras mas modernas (Fibra optica) mientras que otras permanecen casi intactas (Cablemodem)

# %% [markdown]
# #### Accesos totales por provincia

# %%
# Primero sumamos todas las tecnologías para cada fila
df_Accesos_Por_Tecnología["Total"] = df_Accesos_Por_Tecnología[["ADSL", "Cablemodem", "Fibra óptica", "Wireless", "Otros"]].sum(axis=1)

# Agrupamos por Año y Provincia
df_Accesos_Por_Tecnología["Tiempo"] = df_Accesos_Por_Tecnología["Año"].astype(str) + " -T" + df_Accesos_Por_Tecnología["Trimestre"].astype(str)

df_total = df_Accesos_Por_Tecnología.groupby(["Tiempo", "Provincia"])["Total"].sum().unstack()


ax = df_total.plot(kind='line', marker='o', figsize=(14, 7))
# Eje X completo
ax.set_xticks(range(len(df_total.index)))
ax.set_xticklabels(df_total.index, rotation=90)
# Plot de líneas
plt.title("Evolución Total de Accesos por Provincia")
plt.xlabel("Año")
plt.ylabel("Total de Accesos")
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title="Provincia", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Acceso cada 100 hogares y cada 100 habitantes

# %%
df_poblacion_hogares = pd.concat([df_Penetración_poblacion, df_Penetracion_hogares[['Accesos por cada 100 hogares']]], axis=1)
df_poblacion_hogares = df_poblacion_hogares[['Accesos por cada 100 hogares','Accesos por cada 100 hab','Provincia']]
df_poblacion_hogares= df_poblacion_hogares.groupby('Provincia')[['Accesos por cada 100 hab','Accesos por cada 100 hogares']].mean()

# %%
df_poblacion_hogares.plot(kind='bar', stacked=True, figsize=(15, 6))
plt.title('Accesos por cada 100 habitantes y 100 hogares por Provincia')
plt.xticks(rotation=90)
plt.ylabel('Accesos')
plt.show()

# %% [markdown]
# Aclaracion: hay mas conexiones en los hogares que por habitante, un aspecto clave en la economia familiar que nunca se debe pasar por alto. Tambien

# %% [markdown]
# #### Correlacion velocidades vs tipos de tecnologia

# %%
df_Accesos_por_rangos
df_Accesos_Por_Tecnología
# Concatenamos el dataframe de los rangos de velocidad con el de las tecnologias creando una columna temporal y obviando las innecesarias

df_Accesos_por_rangos['Fecha'] = df_Accesos_por_rangos['Año'].astype(str) + ' Q' + df_Accesos_por_rangos['Trimestre'].astype(str)

df_accesos = pd.concat([df_Accesos_por_rangos, df_Accesos_Por_Tecnología], axis=1)

df_accesos = df_accesos.loc[:,~df_accesos.columns.duplicated()]

# %%
corr = df_accesos[['ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros', 
                   'HASTA 512 kbps', '+ 512 Kbps - 1 Mbps', '+ 1 Mbps - 6 Mbps', '+ 6 Mbps - 10 Mbps', 
                   '+ 10 Mbps - 20 Mbps', '+ 20 Mbps - 30 Mbps', '+ 30 Mbps', 'OTROS', 'Total']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de correlación entre columnas")
plt.show()

# %% [markdown]
# En esta correlacion encontramos informacion muy valiosa, porque cuando miramos el mapa de calor nos damos cuenta que existen varias relaciones fuertes entre ciertos rangos de conectividad y las tecnologias, dandole un rango de limites de velocidades a cada tecnologia que a la vez define su capacidad y aplicacion en cierto sentido
#
# Para el ADSL se le otorga un rango entre 512 Kbps y 20Mbps teniendo su aplicacion mas comun entre 1 y 6 Mbps
#
# Para el cablemodem se encuentra entre 6 y +30 Mbps y la fibra optica se aplica desde 30 Mbps en adelante
# Tambien graficamos los ingresos de la industria del internet en funcion del tiempo, pero no es un grafico de gran utilidad ya que esta en una moneda que posee una alta devaluacion por lo que no se puede evaluar su rendimiento financiero en terminos reales

# %% [markdown]
# #### Ingresos

# %%
def division(valor):
    nuevo_valor = round(valor/1000, 2)
    return nuevo_valor

df_Ingresos['Ingresos (millones de pesos)'] = df_Ingresos['Ingresos (miles de pesos)'].apply(division)

# %%
df_Ingresos.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)        Periodo  \
# 0  2024          2               4.420322e+08   Abr-Jun 2024
# 1  2024          1               3.461990e+08   Ene-Mar 2024
# 2  2023          4               1.673760e+08   Oct-Dic 2023
# 3  2023          3               1.331066e+08  Jul-Sept 2023
# 4  2023          2               1.180603e+08   Jun-Mar 2023
#
#    Ingresos (millones de pesos)
# 0                     442032.17
# 1                     346198.99
# 2                     167376.01
# 3                     133106.59
# 4                     118060.28

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Periodo', y='Ingresos (millones de pesos)', data=df_Ingresos, marker='o', sort=True)
plt.gca().invert_xaxis()
plt.title('Evolución de Ingresos en Millones de Pesos por Periodo')
plt.xlabel('Periodo')
plt.ylabel('Ingresos (millones de pesos)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
